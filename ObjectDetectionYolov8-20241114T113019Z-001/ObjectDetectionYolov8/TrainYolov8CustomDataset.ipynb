# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/My Drive/ComputerVisionEngineer/ObjectDetectionYolov8'

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.8/883.8 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")  # load pre trained model

# %%
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=10)
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import shutil

# Kopyalamak istediğiniz kaynak ve hedef dizinleri belirtin
source_dir = '/content/runs'
target_dir = '/content/gdrive/My Drive/ComputerVisionEngineer/ObjectDetectionYolov8/runs'

# Kaynak dizini hedefe kopyala
shutil.copytree(source_dir, target_dir, dirs_exist_ok=True)
# Out:
# '/content/gdrive/My Drive/ComputerVisionEngineer/ObjectDetectionYolov8/runs'
